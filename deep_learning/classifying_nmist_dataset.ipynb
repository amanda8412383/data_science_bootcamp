# %% [markdown]
# ![{2964FD0F-1DC1-4656-9B7E-9A4ADF43D337}.png](attachment:{2964FD0F-1DC1-4656-9B7E-9A4ADF43D337}.png)
#
# ![{3C4C39B2-E109-4C73-8E09-F7379AD175BA}.png](attachment:{3C4C39B2-E109-4C73-8E09-F7379AD175BA}.png)

# %% [markdown]
# ### Vorverarbeitung
#
# Für numerische Werte ist eine Standardisierung (=Feature Scaling) unabdingbar, sonst wird die Größe der Werte die Gewicht verzerren
#
# Für kategorische Eingabe:
# 1. Binary encoding:das ist ein bisschen problematisch, weil Muffin nicht die gegenteil von Brot ist
#
# Kategorie| var 1    | var 2   |
# :- | :- | :-|
# Muffin   | 0        | 1       |
# Brot     | 1        | 0       |
# Jogurt   | 1        | 1       |
#
# 1. One-hot encoding(wie dummy-Variabel)
# Kategorie| Muffin    | Brot  | Jogurt|
# :- | :- | :-| :-|
# Muffin   | 1     | 0      | 0 |
# Brot     | 0        | 1       |0 |
# Jogurt   | 0        | 0   | 1 |
